# %%
import numpy as np
import matplotlib.pyplot as plt
import plot_scripts as plts
plt.style.use("mplstyle")

# %%
dnuc = 40e-3            # MHz
nua = np.load('nua.npy')
N = len(nua)
dnu = np.arange(N)*dnuc

# %%
path = 'results'
mode = 'NOFLAG'
# mode = 'RANDOM'
mode = 'PERIODIC'
mode = 'PERIODIC+RANDOM'
inp_signal = '21cm'
inp_signal = 'FG+21cm'
inp_signal = 'FG+MM+21cm'

SCF = 'Hann'
# mode = 'RANDOM'
data = np.load(f"{path}/CL_inp_signal-{inp_signal}_flag-{mode}_SCF-{SCF}.npz") 
cl              = data["cl"]
inp_signal      = data["inp_signal"].tolist()
flag            = data["flag"].tolist()
scf             = data["SCF"].tolist()
cla_noflag = np.average(cl[20:31], axis=0)

SCF = 'GP'
# mode = 'PERIODIC'
# mode = 'PERIODIC+RANDOM'
# mode = 'RANDOM'

data = np.load(f"{path}/CL_inp_signal-{inp_signal}_flag-{mode}_SCF-{SCF}.npz") 
cl              = data["cl"]
inp_signal      = data["inp_signal"].tolist()
flag            = data["flag"].tolist()
scf             = data["SCF"].tolist()
cla_periodic = np.average(cl[20:31], axis=0)


# SCF = 'GP'
# data = np.load(f"{path}/CL_inp_signal-{inp_signal}_flag-{mode}_SCF-{SCF}.npz") 
# cl1              = data["cl"]
# inp_signal1      = data["inp_signal"].tolist()
# flag1            = data["flag"].tolist()
# scf1             = data["SCF"].tolist()

# %%
cla_noflag.shape, 
nc1 = 660 # len(cla_periodic)

# %%
cla_noflag.shape, cla_periodic.shape
# Out:
# ((667,), (759,))

# %%
nnm = 100
plt.plot(dnu[:nnm], cla_noflag[:nnm])
plt.plot(dnu[:nnm], cla_periodic[:nnm])
# Out:
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(dnu[:nc1], cla_noflag[:nc1])
plt.plot(dnu[:nc1], cla_periodic[:nc1])
plt.show()
# Out:
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(dnu[:nc1], cla_noflag[:nc1])
plt.plot(dnu[:nc1], cla_periodic[:nc1])
# plt.plot(dnu[:nc1], cla_periodic)
plt.show()
# Out:
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(dnu[:nc1], cla_noflag[:nc1]-cla_periodic[:nc1])
# Out:
# /home/asif/miniconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# %%
# Out:
# UsageError: Cell magic `%%` not found.
