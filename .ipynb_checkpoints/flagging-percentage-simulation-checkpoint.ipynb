# %% [markdown]
# ## This notebook tests Bayes-SCF for different flagging pattern and percentages.

# %%
import os

os.environ["OMP_NUM_THREADS"] = "4"
os.environ["OPENBLAS_NUM_THREADS"] = "4"
os.environ["MKL_NUM_THREADS"] = "4"
os.environ["VECLIB_MAXIMUM_THREADS"] = "4"
os.environ["NUMEXPR_NUM_THREADS"] = "4"

import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal.windows import nuttall
from matplotlib.colors import LogNorm
import pkfuncs as pfunc
import scipy
from scipy.signal import windows
import plot_scripts as plts
plt.style.use("mplstyle")

# %%
# input model power spectrum
n = 2.0
N = 768
dnuc = 40e-3            # MHz
r = 9209.714526830916 # Mpc
rp = 16.98990953034521  # Mpc/MHz
dL = dnuc * rp
L  = N * dL
Nrea = 100

# EoR 21-cm PS for Mondal+17
PK21 = np.load('PK21.npy')
k_model = PK21[:, 0]
P_model = PK21[:, 1]
# P_model = k_model**(-n)


k_fft = 2*np.pi*np.arange(N)/L

# kper = 0.1
# k_fft = np.sqrt( k_fft**2 + kper**2 ) 

k_abs = np.abs(k_fft)

P_cont = np.interp(k_abs, k_model, P_model , left=0, right=0)

# Discrete variance for FFT modes
P_dft = (N**2 / L) * P_cont 
# P_dft = L * P_cont 
# P_dft = P_cont 

# binning 
NB = 64  # number of bins
# NN_gp = 32
# NN_gp = 64
NN_gp = 96
# NN_gp = 112
# NN_gp = 128

# %%
# INP_SIGNAL_CONFIGS = {
#     "21cm": dict(type="21cm"),
#     "FG+21cm": dict(type="FG+21cm"),
#     "FG+MM+21cm": dict(type="FG+MM+21cm"),
# }
INP_SIGNAL_CONFIGS = {
    # "21cm": dict(type="21cm"),
    "FG+MM+21cm": dict(type="FG+MM+21cm"),
}

# # -----------------------------
# # FLAG configurations
# # -----------------------------
# FLAG_CONFIGS = {
#     "NOFLAG": dict(mode="NOFLAG", percent=0, seed=42),
#     "RANDOM35": dict(mode="RANDOM", percent=35, seed=42),
#     "PERIODIC": dict(mode="PERIODIC", percent=0, seed=42),
#     "PERIODIC+RANDOM10": dict(mode="PERIODIC+RANDOM", percent=10, seed=42),
# }

FLAG_CONFIGS = {
    # "RANDOM30": dict(mode="RANDOM30", percent=30, seed=42),
    # "RANDOM40": dict(mode="RANDOM40", percent=40, seed=42),
    # "RANDOM50": dict(mode="RANDOM50", percent=50, seed=42),
    # "RANDOM60": dict(mode="RANDOM60", percent=60, seed=42),
    # "RANDOM70": dict(mode="RANDOM70", percent=70, seed=42),
    # "RANDOM80": dict(mode="RANDOM80", percent=80, seed=42), # 100
    # "RANDOM81": dict(mode="RANDOM81", percent=80, seed=42), # 500
    # "RANDOM82": dict(mode="RANDOM82", percent=80, seed=42), # 1000
    # "RANDOM90": dict(mode="RANDOM90", percent=90, seed=42),
    # "RANDOM91": dict(mode="RANDOM91", percent=90, seed=42),
    # "RANDOM92": dict(mode="RANDOM92", percent=90, seed=42),
    # "BROADBAND03": dict(mode="BROADBAND03", percent=3, seed=42),
    # "BROADBAND10": dict(mode="BROADBAND10", percent=10, seed=42),
    # "BROADBAND30": dict(mode="BROADBAND30", percent=30, seed=42),
    # "BROADBAND50": dict(mode="BROADBAND50", percent=50, seed=42),
    "BROADBAND51": dict(mode="BROADBAND51", percent=50, seed=42),
    # "BROADBAND80": dict(mode="BROADBAND80", percent=80, seed=42),
}


# # -----------------------------
# # SCF configurations
# # -----------------------------
# SCF_CONFIGS = {
#     "None": dict(SCF="None", NN_gp=None, NN_hann=None),
#     "GP":   dict(SCF="GP",   NN_gp=96,  NN_hann=None),
#     "Hann": dict(SCF="Hann", NN_gp=None, NN_hann=50),
# }

SCF_CONFIGS = {
    "GP":   dict(SCF="GP",   NN_gp=NN_gp,  NN_hann=None),
}

# %%
def generate_fields(inp_signal, *, N, Nrea, P_dft):
    # 21-cm realizations (always needed)
    fields_21cm = np.array(
        [pfunc.draw_field_from_power(P_dft, seed=55 + i) for i in range(Nrea)]
    )

    if inp_signal == "21cm":
        return fields_21cm

    if inp_signal == "FG+21cm":
        fields_forg = pfunc.generate_gp_realizations(
            Npoints=N,
            amplitude=1e12,
            length_scale=1e4,
            Nreal=Nrea,
            kernel_type="RBF",
            sigma=1, seed=42,
        )
        return fields_forg + fields_21cm

    if inp_signal == "FG+MM+21cm":
        fields_forg = pfunc.generate_gp_realizations(
            Npoints=N,
            amplitude=1e12,
            length_scale=100,
            Nreal=Nrea,
            kernel_type="RBF",
            sigma=1, seed=42,
        )
        return fields_forg + fields_21cm

    raise ValueError(f"Unknown inp_signal: {inp_signal}")

# %%
# fname = f"fft_inp_signal-{inp_signal}_flag-{flag}_SCF-{SCF}_NN-{NN_gp}.npz"
# fname

# %%
def run_one_configuration(
    fields_tota,
    inp_signal,
    flag_cfg,
    scf_cfg,
    *,
    N, L, dL, r, NB,
    k_model, P_model,
    P_cont, k_abs,
    path="results"
):
    # -----------------------------
    os.makedirs(path, exist_ok=True)
    # -----------------------------
    flag = pfunc.flagdata(
        N,
        mode=flag_cfg["mode"],
        percent=flag_cfg["percent"],
        seed=flag_cfg["seed"],
    )

    flag_percent = 100 * (1 - np.count_nonzero(flag) / N)
    print(
        f"[FLAG={flag_cfg['mode']}, SCF={scf_cfg['SCF']}] "
        f"flagged = {flag_percent:.1f}%"
    )

    # -----------------------------
    # SCF processing
    # -----------------------------
    fields_tota = fields_tota*flag
    fields_orig, fields_flag, ml = pfunc.process_scf(
        fields_tota,
        flag,
        scf_cfg["SCF"],
        NN_gp=scf_cfg["NN_gp"],
        NN_hann=scf_cfg["NN_hann"], verbose=True
    )
    
    plt.plot(fields_flag[0])
    plt.show()
    
    # -----------------------------
    # FFT estimator
    # -----------------------------
    pk_fft = pfunc.pk_fft(fields_flag, L, N)

    n1_fft, nend_fft = 0, N // 2
    kb_fft, mean_fft, err_fft, binned_th_fft, _ = pfunc.bin_power_spectrum(
        n1_fft, nend_fft,
        k_abs[n1_fft:nend_fft],
        pk_fft,
        P_cont,
        NB
    )

    # -----------------------------
    # DCT estimator
    # -----------------------------
    M = np.argmax(ml.real == 0) if np.any(ml.real == 0) else ml.shape[0]
    print(M)
    k_dct = np.pi * np.arange(M) / ((M - 1) * dL)
    # print(k_dct)
    
    P_cont_dct = np.interp(k_dct, k_model, P_model, left=0, right=0)
    w = windows.nuttall(2*M)[M:]
    pk_dct, cl = pfunc.pk_dct(fields_flag, dL, ml, M, r, w)

    kb_dct, mean_dct, err_dct, binned_th_dct, _ = pfunc.bin_power_spectrum(
        0, M, k_dct, pk_dct, P_cont_dct, NB
    )

    # -----------------------------
    # Save outputs
    # -----------------------------
    flag_name = flag_cfg["mode"]
    SCF = scf_cfg["SCF"]

    # Construct filename matching your save_data style
    fields_fname = f"{path}/fields_inp_signal-{inp_signal}_flag-{flag_name}_SCF-{SCF}_NN-{NN_gp}.npz"

    # Only save if the file does not exist
    # if not os.path.exists(fields_fname):
    # print(f"Saving fields to {fields_fname}...")
    np.savez(
        fields_fname,
        fields_tota=fields_tota,
        fields_orig=fields_orig,
        fields_flag=fields_flag,
        # Metadata (optional but helpful)
        inp_signal=inp_signal,
        flag=flag_name,
        SCF=SCF
    )

    pfunc.save_data(
        fname_prefix = f"{path}/fft",
        inp_signal=inp_signal,
        flag=flag_name,
        SCF=SCF,
        kb=kb_fft,
        mean=mean_fft,
        err=err_fft,
        binned_th=binned_th_fft,
        fname = f"{path}/fft_inp_signal-{inp_signal}_flag-{flag_name}_SCF-{SCF}_NN-{NN_gp}.npz"
    )

    pfunc.save_data(
        fname_prefix = f"{path}/dct",
        inp_signal=inp_signal,
        flag=flag_name,
        SCF=SCF,
        kb=kb_dct,
        mean=mean_dct,
        err=err_dct,
        binned_th=binned_th_dct,
        fname = f"{path}/dct_inp_signal-{inp_signal}_flag-{flag_name}_SCF-{SCF}_NN-{NN_gp}.npz"
    )

    np.savez(
        # f"{path}/CL_inp_signal-{inp_signal}_flag-{flag_name}_SCF-{SCF}.npz",
        f"{path}/CL_inp_signal-{inp_signal}_flag-{flag_name}_SCF-{SCF}_NN-{NN_gp}.npz",
        cl=cl,
        inp_signal=inp_signal,
        flag=flag,
        SCF=SCF,
    )

# %%
# from tqdm.notebook import tqdm  # Use 'tqdm' if running in a script
from tqdm import tqdm

# Wrap your outer loop with tqdm
for inp_signal in tqdm(INP_SIGNAL_CONFIGS, desc="Signals"):

    print(f"\n=== Running inp_signal = {inp_signal} ===")
    
    fields_tota = generate_fields(
        inp_signal,
        N=N, Nrea=Nrea, P_dft=P_dft,
    )

    

    # You can also wrap inner loops if they are long
    for flag_key, flag_cfg in FLAG_CONFIGS.items():
        for scf_key, scf_cfg in SCF_CONFIGS.items():
            
            run_one_configuration(
                fields_tota=fields_tota,
                inp_signal=inp_signal,
                flag_cfg=flag_cfg,
                scf_cfg=scf_cfg,
                N=N, L=L, dL=dL, r=r, NB=NB,
                k_model=k_model,
                P_model=P_model,
                P_cont=P_cont,
                k_abs=k_abs,
                path="results_RANDOM",
            )
# Out:
# Signals:   0%|                                                                                    | 0/1 [00:00<?, ?it/s]
# === Running inp_signal = FG+MM+21cm ===
# [FLAG=BROADBAND51, SCF=GP] flagged = 50.0%
# (768,)
# /Users/asifelahi/MWA/Bayes-SCF/pkfuncs.py:457: RuntimeWarning: invalid value encountered in divide
#   cl_full = covtocl_fast(field, field)/ml
# Signals: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:33<00:00, 33.09s/it]
# 384

# %%
# Plot

# %%
def FGname(inp_signal):
    if (inp_signal == '21cm'):
        FG = 'None'
        dataname = '21cm'
    elif (inp_signal == 'FG+21cm'):
        FG = 'Smooth'
        dataname = 'FG'
    elif (inp_signal == 'FG+MM+21cm'):
        FG = 'Unsmooth'
        dataname = 'FGMM'
    return FG, dataname

# %%
inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['RANDOM40', 'RANDOM50', 'RANDOM60', 'RANDOM70', 'RANDOM80']
colors = ['C0', 'C1', 'C2', 'C3', 'C4']
fmts = ['o', 's', '^', '>', '*']
lss = ['--', '-.', ':', '--', '-.']


FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 210
shift, ylim = 1.0, 12
shift, ylim = 1.0, 210
 
figname = f"plots/{dataname}_{SCF}_RANDOM_flag.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 14))
gs  = fig.add_gridspec(
    6, 1,
    height_ratios=[3, 1, 1, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 6)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    kb_fft        = data["kb"]
    mean_fft      = data["mean"]
    err_fft       = data["err"]
    binned_th_fft = data["binned_th"]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \%$" 

    )
    # # mark negative values with 'x'
    # negmask = mean_fft < 0
    
    # ax1.plot(
    #     kb_fft[negmask],
    #     abs(mean_fft[negmask]) * shift,
    #     marker='x',
    #     ls='None',
    #     ms=7,
    #     mew=1.5,
    #     # color=color
    #     color='magenta'
    # )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        fr"$ff = \rm{{ {ff} }} \%$",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=2e3)
ax1.set_ylim(-2e3, 1e6)
ax1.set_ylabel(r'$ P(k_\parallel)  \, {\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = FG+MM+21cm, flag = RANDOM40, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM50, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM60, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM70, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM80, scf = GP
# Saved: plots/FGMM_GP_RANDOM_flag.pdf

# %%
SCF        = "GP"
FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 50
 
figname = f"plots/{dataname}_{SCF}_RANDOM_flag_zoom.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 14))
gs  = fig.add_gridspec(
    6, 1,
    height_ratios=[3, 1, 1, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 6)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 27
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        ls='--',
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \%$" 

    )
    # # mark negative values with 'x'
    # negmask = mean_fft < 0
    
    # ax1.plot(
    #     kb_fft[negmask],
    #     (mean_fft[negmask]) * shift,
    #     marker='x',
    #     ls='None',
    #     ms=7,
    #     mew=1.5,
    #     # color=color
    #     color='magenta'
    # )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        fr"$ff = \rm{{ {ff} }} \%$", 
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=1e3)
ax1.set_ylim(-5e3, 1e6)
ax1.set_ylabel(r'$\mid P(k_\parallel) \mid \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()


zoom_figname = f"plots/{dataname}_{SCF}_RANDOM_flag_zoom.pdf"

fig.savefig(zoom_figname, bbox_inches='tight')
print("Saved:", zoom_figname)
# Out:
# inp_signal = FG+MM+21cm, flag = RANDOM40, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM50, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM60, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM70, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM80, scf = GP
# Saved: plots/FGMM_Bayes_RANDOM_flag_zoom.pdf

# %% [markdown]
# # 80%, with more realization

# %%
inp_signal = "21cm"
inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['RANDOM90', 'RANDOM91', 'RANDOM92']
modes  = ['RANDOM80', 'RANDOM81', 'RANDOM82']
colors = ['C4', 'C5', 'C7']
fmts = ['*', 'o', 's']
nreal = [100, 500, 1000]
lss = ['--', '-.', ':']

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 210
shift, ylim = 1.0, 12
shift, ylim = 1.0, 210
 
figname = f"plots/{dataname}_{SCF}_RANDOM_flag80.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 100
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $" 

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$ff = 80\%$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=1e3)
ax1.set_ylim(-5e3, 1e6)
ax1.set_ylabel(r'$\mid P(k_\parallel) \mid \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = FG+MM+21cm, flag = RANDOM80, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM81, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM82, scf = GP
# Saved: plots/FGMM_GP_RANDOM_flag80.pdf

# %%
shift, ylim = 1.0, 50


# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 27
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $" 

    )
    

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$ff = 80\%$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=1e3)
ax1.set_ylim(-5e3, 1e6)

ax1.set_ylabel(r'$\mid P(k_\parallel) \mid \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)
axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()

zoom_figname = f"plots/{dataname}_{SCF}_RANDOM_flag80_zoom.pdf"

fig.savefig(zoom_figname, bbox_inches='tight')
print("Saved:", zoom_figname)
# Out:
# inp_signal = FG+MM+21cm, flag = RANDOM80, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM81, scf = GP
# inp_signal = FG+MM+21cm, flag = RANDOM82, scf = GP
# Saved: plots/FGMM_Bayes_RANDOM_flag80_zoom.pdf

# %% [markdown]
# # 21cm

# %%
inp_signal = "21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['RANDOM90', 'RANDOM91', 'RANDOM92']
modes  = ['RANDOM80', 'RANDOM81', 'RANDOM82']
colors = ['C4', 'C5', 'C7']
fmts = ['*', 'o', 's']
nreal = [100, 500, 1000]
lss = ['--', '-.', ':']

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 210
shift, ylim = 1.0, 12
shift, ylim = 1.0, 210
 
figname = f"plots/{dataname}_{SCF}_RANDOM_flag80.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 100
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $" 

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$ff = 80\%$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=1e3)
ax1.set_ylim(-5e3, 1e6)
ax1.set_ylabel(r'$\mid P(k_\parallel) \mid \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = 21cm, flag = RANDOM80, scf = GP
# inp_signal = 21cm, flag = RANDOM81, scf = GP
# inp_signal = 21cm, flag = RANDOM82, scf = GP
# Saved: plots/21cm_GP_RANDOM_flag80.pdf

# %%
shift, ylim = 1.0, 50


# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 27
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])

    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.5,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $" 

    )
    

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$ff = 80\%$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$N_{ \rm{rea} }$" + fr"$ =  {nreal[i]}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
# ax1.set_yscale('log')
ax1.set_yscale('symlog', linthresh=1e3)
ax1.set_ylim(-5e3, 1e6)

ax1.set_ylabel(r'$\mid P(k_\parallel) \mid \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)
axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()

zoom_figname = f"plots/{dataname}_{SCF}_RANDOM_flag80_zoom.pdf"

fig.savefig(zoom_figname, bbox_inches='tight')
print("Saved:", zoom_figname)
# Out:
# inp_signal = 21cm, flag = RANDOM80, scf = GP
# inp_signal = 21cm, flag = RANDOM81, scf = GP
# inp_signal = 21cm, flag = RANDOM82, scf = GP
# Saved: plots/21cm_Bayes_RANDOM_flag80_zoom.pdf

# %% [markdown]
# # Broadband RFI

# %%
inp_signal = "21cm"
# inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['BROADBAND10', 'BROADBAND30', 'BROADBAND50']
# modes  = ['BROADBAND03', 'BROADBAND10', 'BROADBAND30']
colors = ['C4', 'C5', 'C7']
fmts = ['*', 'o', 's']
nreal = [100, 500, 1000]
lss = ['--', '-.', ':']

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 50
shift, ylim = 1.0, 12
shift, ylim = 1.0, 20
# shift, ylim = 1.0, 50
 
figname = f"plots/{dataname}_{SCF}_broadband.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 100
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])


    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \%$"

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$\rm{Broadband}$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$ff$" + fr"$ =  {ff}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
ax1.set_yscale('log')
# ax1.set_yscale('symlog', linthresh=1e1)
# ax1.set_ylim(-5e1, 1e6)
ax1.set_ylabel(r'$ P(k_\parallel)  \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = 21cm, flag = BROADBAND10, scf = GP
# inp_signal = 21cm, flag = BROADBAND30, scf = GP
# inp_signal = 21cm, flag = BROADBAND50, scf = GP
# Saved: plots/21cm_GP_broadband.pdf

# %%
inp_signal = "21cm"
# inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['BROADBAND10', 'BROADBAND30', 'BROADBAND50']
# modes  = ['BROADBAND03', 'BROADBAND10', 'BROADBAND30']
colors = ['C4', 'C5', 'C7']
fmts = ['*', 'o', 's']
nreal = [100, 500, 1000]
lss = ['--', '-.', ':']

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 50
shift, ylim = 1.0, 20
# shift, ylim = 1.0, 50
 
figname = f"plots/{dataname}_{SCF}_broadband_zoom.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 27
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])


    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \%$"

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$\rm{Broadband}$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$ff$" + fr"$ =  {ff}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
ax1.set_yscale('log')
# ax1.set_yscale('symlog', linthresh=1e1)
# ax1.set_ylim(-5e1, 1e6)
ax1.set_ylabel(r'$ P(k_\parallel)  \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = 21cm, flag = BROADBAND10, scf = GP
# inp_signal = 21cm, flag = BROADBAND30, scf = GP
# inp_signal = 21cm, flag = BROADBAND50, scf = GP
# Saved: plots/21cm_GP_broadband_zoom.pdf

# %%
inp_signal = "21cm"
inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['BROADBAND10', 'BROADBAND30', 'BROADBAND50', 'BROADBAND51']
colors = ['C4', 'C5', 'C7', 'C8']
fmts = ['*', 'o', 's', 'd']
nreal = [100, 500, 1000]
lss = ['-', '-.', ':', '--']


# ff and position for each mode (BROADBAND51 is a distinct edge-positioned
# 50% gap; the trailing "51" is just a label, not the actual percentage)
ff_map  = {'BROADBAND10': 10, 'BROADBAND30': 30, 'BROADBAND50': 50, 'BROADBAND51': 50}
pos_map = {'BROADBAND10': 'centre', 'BROADBAND30': 'centre', 'BROADBAND50': 'centre', 'BROADBAND51': 'edge'}

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 50
shift, ylim = 1.0, 12
shift, ylim = 1.0, 20
# shift, ylim = 1.0, 50

figname = f"plots/{dataname}_{SCF}_broadband.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 13))
gs  = fig.add_gridspec(
    5, 1,
    height_ratios=[3, 1, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 5)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 100
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = ff_map[mode]
    label_tag = r"\rm{(edge)}" if pos_map[mode] == 'edge' else r"\rm{(centre)}"


    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \% \ {label_tag}$"

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$\rm{Broadband}$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$ff$" + fr"$ =  {ff}  $" + f"  {label_tag}",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)

    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')


# --------------------------------------------------
ax1.set_yscale('log')
# ax1.set_yscale('symlog', linthresh=1e1)
# ax1.set_ylim(-5e1, 1e6)
ax1.set_ylabel(r'$ P(k_\parallel)  \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",

)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = FG+MM+21cm, flag = BROADBAND10, scf = GP
# inp_signal = FG+MM+21cm, flag = BROADBAND30, scf = GP
# inp_signal = FG+MM+21cm, flag = BROADBAND50, scf = GP
# inp_signal = FG+MM+21cm, flag = BROADBAND51, scf = GP
# Saved: plots/FGMM_GP_broadband.pdf

# %%
inp_signal = "21cm"
inp_signal = "FG+MM+21cm"
SCF        = "GP"
path       = "results_RANDOM"
# modes  = ['NOFLAG']
# colors = ['C1']
# fmts = ['s']


modes  = ['BROADBAND10', 'BROADBAND30', 'BROADBAND50']
# modes  = ['BROADBAND03', 'BROADBAND10', 'BROADBAND30']
colors = ['C4', 'C5', 'C7']
fmts = ['*', 'o', 's']
nreal = [100, 500, 1000]
lss = ['--', '-.', ':']

FG, dataname = FGname(inp_signal)
shift, ylim = 1.0, 50
shift, ylim = 1.0, 20
# shift, ylim = 1.0, 50
 
figname = f"plots/{dataname}_{SCF}_broadband_zoom.pdf"
os.makedirs("plots", exist_ok=True)

# --------------------------------------------------
# FIGURE LAYOUT
# --------------------------------------------------
fig = plt.figure(figsize=(7, 11))
gs  = fig.add_gridspec(
    4, 1,
    height_ratios=[3, 1, 1, 1],
    hspace=0.07
)

ax1 = fig.add_subplot(gs[0])
axd = [fig.add_subplot(gs[i], sharex=ax1) for i in range(1, 4)]


# --------------------------------------------------
# LOOP OVER FLAG PATTERNS
# --------------------------------------------------
for i, (mode, color, fmt) in enumerate(zip(modes, colors, fmts)):

    # ---------- Load data ----------
    data = np.load(
        f"{path}/dct_inp_signal-{inp_signal}_flag-{mode}_SCF-GP_NN-96.npz"
    )

    n1 = 27
    kb_fft        = data["kb"][:n1]
    mean_fft      = data["mean"][:n1]
    err_fft       = data["err"][:n1]
    binned_th_fft = data["binned_th"][:n1]

    inp_signal1 = data["inp_signal"].tolist()
    flag1       = data["flag"].tolist()
    scf1        = data["SCF"].tolist()

    print(f"inp_signal = {inp_signal1}, flag = {flag1}, scf = {scf1}")
    ff = int(mode[-2:])


    # ---------- TOP PANEL: power spectra ----------
    ax1.errorbar(
        kb_fft,
        # abs(mean_fft) * shift,
        (mean_fft) * shift,
        err_fft * shift,
        ms=4,
        elinewidth=0.1,
        fmt=fmt,
        # ls='--',
        ls=lss[i],
        color=color,
        ecolor=(*plt.matplotlib.colors.to_rgb(color), 0.3),  # transparent error bars
        label=fr"$ff = \rm{{ {ff} }} \%$"

    )

    if i == 0:
        ax1.plot(
            kb_fft,
            binned_th_fft * shift,
            '-k',
            lw=2,
            label=r'${\rm EoR\,Model}$'
        )

        ax1.text(
            0.5, 0.9,
            r"$\rm{Broadband}$",
            transform=ax1.transAxes,
            ha='center',
            va='top',
            bbox=dict(
                facecolor='white',
                edgecolor='black',
                alpha=0.5,   # transparency
                boxstyle='round,pad=0.3'
            ),
            # fontsize=10
        )

    # ---------- Deviation ----------
    ratio = 100.0 * (mean_fft / binned_th_fft - 1.0)
    err_r = 100.0 * err_fft / binned_th_fft

    axd[i].errorbar(
        kb_fft,
        ratio,
        err_r,
        ms=4,
        elinewidth=1,
        fmt=fmt,
        color=color
    )


    axd[i].fill_between(kb_fft, -err_r, err_r,
                        color=color, alpha=0.2,
                        label="_nolegend_")

    axd[i].axhline(0, color='k', ls='--')
    # axd[i].grid(alpha=0.3)
    axd[i].set_ylabel(r'\rm{\%\,deviation}')
    # axd[i].set_xscale('log')

    axd[i].text(
        0.02, 0.85,
        r"$ff$" + fr"$ =  {ff}  $",
        transform=axd[i].transAxes,
        # fontsize=10
    )

    if ylim is not None:
        axd[i].set_ylim(-ylim, ylim)
    
    # axd[-1].set_ylim(1e3, 3e5)
    # axd[-2].set_ylim(-1e2, 1e2)
    # axd[-1].set_yscale('log')

    
# --------------------------------------------------
ax1.set_yscale('log')
# ax1.set_yscale('symlog', linthresh=1e1)
# ax1.set_ylim(-5e1, 1e6)
ax1.set_ylabel(r'$ P(k_\parallel)  \,{\rm mK}^2\,{\rm Mpc}$')
# ax1.grid(alpha=0.3)
ax1.legend(loc=1)
ax1.tick_params(labelbottom=False)

for ax in axd[:-1]:
    ax.tick_params(labelbottom=False)

axd[-1].tick_params(labelbottom=True)


axd[-1].set_xlabel(r'$k_\parallel\,{\rm Mpc}^{-1}$')

SCF = 'Bayes'
ax1.set_title(
    r"\rm{{\bf FG:}~}" + fr"\rm{{{FG}}}"
    + r"\rm{\quad {\bf Method:}~}" + r'${ \mathcal{F} [ C(\Delta\nu) ] }$'
    + r"\rm{\quad {\bf SCF:}~}" + fr"$\mathrm{{{SCF}}}$",
    
)

fig.align_ylabels()
fig.savefig(figname, bbox_inches='tight')
print("Saved:", figname)
# Out:
# inp_signal = FG+MM+21cm, flag = BROADBAND10, scf = GP
# inp_signal = FG+MM+21cm, flag = BROADBAND30, scf = GP
# inp_signal = FG+MM+21cm, flag = BROADBAND50, scf = GP
# Saved: plots/FGMM_GP_broadband_zoom.pdf
